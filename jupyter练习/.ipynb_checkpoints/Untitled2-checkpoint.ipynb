# %%
import pandas as pd
import numpy as np
import xlrd

path1 = r'C:\Users\x\Desktop\【生意参谋】商品效果-2018-09-01-2018-09-01.xls'
path2 = r'C:\Users\x\Desktop\【生意参谋】商品效果-2018-09-02-2018-09-02.xls'
df1 = pd.read_excel(path1)
df2 = pd.read_excel(path2)
# Out:
#     数据说明：以下数据为您所选条件筛选的宝贝（最多展示3600个宝贝）及其相关指标，如需查看其他时间周期的数据，请重新选择后下载  \
# 0                  收藏网址：d.alibaba.com，让数据帮您生意参谋！点此进入>>
# 1                                                  NaN
# 2                                                 所属终端
# 3                                                 所有终端
# 4                                                 所有终端
# 5                                                 所有终端
# 6                                                 所有终端
# 7                                                 所有终端
# 8                                                 所有终端
# 9                                                 所有终端
# 10                                                所有终端
# 11                                                所有终端
# 12                                                所有终端
# 13                                                所有终端
# 14                                                所有终端
# 15                                                所有终端
# ...
