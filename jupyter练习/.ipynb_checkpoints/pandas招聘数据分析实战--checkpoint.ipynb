# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DataAnalyst.csv',encoding = 'gbk')

# %%
df
# Out:
#      city        companyFullName  companyId  \
# 0      上海         纽海信息技术(上海)有限公司       8581
# 1      上海       上海点荣金融信息服务有限责任公司      23177
# 2      上海         上海晶樵网络信息技术有限公司      57561
# 3      上海      杭州数云信息技术有限公司上海分公司       7502
# 4      上海         上海银基富力信息技术有限公司     130876
# 5      上海          上海青之桐投资管理有限公司      28095
# 6      上海           上海好体信息科技有限公司       2002
# 7      上海         上海安硕信息技术股份有限公司      21863
# 8      上海         上海崇杏健康管理咨询有限公司     121208
# 9      上海       五五海淘（上海）科技股份有限公司      58109
# 10     上海          莉莉丝科技（上海）有限公司       1938
# 11     上海           我厨（上海）科技有限公司      51223
# 12     上海           上海阑途信息技术有限公司      36009
# 13     上海           上海麦子资产管理有限公司      63922
# 14     上海           上海如旺电子商务有限公司      48294
# 15     上海       上海点荣金融信息服务有限责任公司      23177
# 16     上海      杭州数云信息技术有限公司上海分公司       7502
# 17     上海           上海好体信息科技有限公司       2002
# 18     上海         上海君同德翔管理咨询有限公司     149677
# 19     上海           上海清源绿网科技有限公司      57577
# 20     上海        上海融之家金融信息服务有限公司      93141
# 21     上海           上海远目投资管理有限公司     143807
# 22     上海           北京数字新思科技有限公司      73539
# 23     上海             上海甫田贸易有限公司     146592
# 24     上海           伽蓝（集团）股份有限公司       7069
# 25     上海         路通世纪(中国)科技有限公司      25499
# 26     上海  中国四达国际经济技术合作有限公司上海分公司      47063
# 27     上海             银联数据服务有限公司     113080
# 28     上海       上海点荣金融信息服务有限责任公司      23177
# 29     上海      杭州数云信息技术有限公司上海分公司       7502
# ...   ...                    ...        ...
# 6846   北京      新华网亿连（北京）科技有限责任公司     153850
# 6847   北京        CBC(北京)信用管理有限公司      64755
# 6848   北京       德通汇富（北京）资本管理有限公司     125706
# 6849   北京              中数通信息有限公司      23448
# 6850   北京         北京华电天益信息科技有限公司      71471
# 6851   北京           北京天会创业投资有限公司     103414
# 6852   北京       数临天下医信科技（北京）有限公司     149114
# 6853   北京           中金金融认证中心有限公司      31317
# 6854   北京           格图（北京）科技有限公司      33479
# 6855   北京              光明网传媒有限公司      30596
# 6856   北京             大公信用统计有限公司      83189
# 6857   北京          北京瑞商源科技有限责任公司      48605
# 6858   北京         北京乐畅乐享文化发展有限公司     144804
# 6859   北京         北京亿盛融华投资管理有限公司     151898
# 6860   北京       德通汇富（北京）资本管理有限公司     125706
# 6861   北京             大公信用统计有限公司      83189
# 6862   北京       北京玛赫西计算机教育咨询有限公司     107608
# 6863   北京       北京丽兹行房地产投资顾问有限公司     124195
# 6864   北京       北京东方弘道资产管理有限责任公司      50518
# 6865   北京         佰润明辉（北京）投资有限公司     121899
# 6866   北京       云联世纪（北京）数据服务有限公司     146872
# 6867   北京           福建省中天地征信有限公司     138882
# 6868   北京         北京亿盛融华投资管理有限公司     151898
# 6869   北京         北京亿盛融华投资管理有限公司     151898
# 6870   北京         北京亿盛融华投资管理有限公司     151898
# 6871   北京         北京亿盛融华投资管理有限公司     151898
# 6872   北京         北京亿盛融华投资管理有限公司     151898
# 6873   北京         北京亿盛融华投资管理有限公司     151898
# 6874   北京         北京亿盛融华投资管理有限公司     151898
# 6875   北京         北京亿盛融华投资管理有限公司     151898
#
#                           companyLabelList   companyShortName companySize  \
# 0         ['技能培训', '节日礼物', '带薪年假', '岗位晋升']                1号店     2000人以上
# 1         ['节日礼物', '带薪年假', '岗位晋升', '扁平管理']                点融网   500-2000人
# 2         ['技能培训', '绩效奖金', '岗位晋升', '管理规范']                SPD     50-150人
# 3         ['绩效奖金', '股票期权', '五险一金', '通讯津贴']                 数云    150-500人
# 4         ['年底双薪', '通讯津贴', '定期体检', '绩效奖金']               银基富力      15-50人
# 5           ['美女多', '出国旅游', '不打卡', '带薪年假']               青桐资本     50-150人
# 6          ['年底双薪', '股票期权', '扁平管理', '领导好']               足球魔方    150-500人
# 7         ['岗位晋升', '顶尖团队', '福利优厚', '股票期权']     安硕信息（amarsoft）     2000人以上
# 8          ['扁平管理', '弹性工作', '岗位晋升', '领导好']               上海崇杏      15-50人
# 9         ['股票期权', '带薪年假', '绩效奖金', '岗位晋升']               55海淘    150-500人
# 10     ['都是萌妹子', '项目奖金', '零食无限量', '国内外旅游']              莉莉丝游戏    150-500人
# 11        ['节日礼物', '技能培训', '带薪年假', '岗位晋升']       我厨（上海）科技有限公司    150-500人
# 12        ['技能培训', '节日礼物', '免费班车', '绩效奖金']              途虎养车网   500-2000人
# 13    ['工资自己定', '期权任性发', '金融狂人聚集', '半年晋升']               麦子金服   500-2000人
# 14        ['年底双薪', '节日礼物', '技能培训', '免费班车']           旺旺集团火热招聘     50-150人
# 15        ['节日礼物', '带薪年假', '岗位晋升', '扁平管理']                点融网   500-2000人
# 16        ['绩效奖金', '股票期权', '五险一金', '通讯津贴']                 数云    150-500人
# 17         ['年底双薪', '股票期权', '扁平管理', '领导好']               足球魔方    150-500人
# 18                                     NaN    Juntong Capital       少于15人
# 19        ['节日礼物', '带薪年假', '绩效奖金', '扁平管理']              清源大数据      15-50人
# 20        ['年底双薪', '股票期权', '带薪年假', '绩效奖金']                融之家   500-2000人
# 21                                     NaN               大观资本       少于15人
# 22         ['年底双薪', '带薪年假', '年度旅游', '领导好']               数字新思      15-50人
# 23         ['带薪年假', '技能培训', '管理规范', '帅哥多']          甫田网Fields    150-500人
# 24        ['绩效奖金', '年底双薪', '五险一金', '通讯津贴']                 伽蓝     2000人以上
# 25        ['五险一金', '免费班车', '绩效奖金', '年底双薪']               汤森路透     2000人以上
# 26        ['技能培训', '带薪年假', '绩效奖金', '岗位晋升']               中国四达     50-150人
# 27                                     NaN               银联数据   500-2000人
# 28        ['节日礼物', '带薪年假', '岗位晋升', '扁平管理']                点融网   500-2000人
# 29        ['绩效奖金', '股票期权', '五险一金', '通讯津贴']                 数云    150-500人
# ...                                    ...                ...         ...
# 6846                                   NaN  新华网亿连（北京）科技有限责任公司      15-50人
# 6847      ['技能培训', '节日礼物', '专项奖金', '带薪年假']                CBC   500-2000人
# 6848       ['带薪年假', '弹性工作', '领导好', '管理规范']               德通汇富     50-150人
# 6849      ['五险一金', '节日礼物', '岗位晋升', '带薪年假']                中数通   500-2000人
# 6850       ['技能培训', '绩效奖金', '领导好', '交通补助']     北京华电天益信息科技有限公司     50-150人
# 6851        ['带薪年假', '领导好', '帅哥多', '交通补助']               天会创投      15-50人
# 6852                                   NaN               数临天下      15-50人
# 6853      ['年底双薪', '绩效奖金', '管理规范', '定期体检']           中国金融认证中心   500-2000人
# 6854       ['股票期权', '年度旅游', '扁平管理', '领导好']                 格图       少于15人
# 6855      ['年底双薪', '节日礼物', '技能培训', '绩效奖金']                光明网    150-500人
# 6856       ['技能培训', '带薪年假', '五险一金', '帅哥多']               大公征信   500-2000人
# 6857      ['带薪年假', '绩效奖金', '岗位晋升', '年度旅游']                瑞商网      15-50人
# 6858       ['绩效奖金', '午餐补助', '技能培训', '领导好']             大玩家超乐场     2000人以上
# 6859                                   NaN               亿盛资本    150-500人
# 6860       ['带薪年假', '弹性工作', '领导好', '管理规范']               德通汇富     50-150人
# 6861       ['技能培训', '带薪年假', '五险一金', '帅哥多']               大公征信   500-2000人
# 6862     ['赴美工作', '美元薪水', '告别996', '技术前沿']             MUM计算机       少于15人
# 6863                                   NaN                丽兹行   500-2000人
# 6864      ['节日礼物', '管理规范', '定期体检', '年终分红']               弘道资本       少于15人
# 6865                                   NaN               佰润明辉    150-500人
# 6866       ['弹性工作', '节日礼物', '领导好', '五险一金']               云联数据       少于15人
# 6867                                   NaN              中天地征信     50-150人
# 6868                                   NaN               亿盛资本    150-500人
# 6869                                   NaN               亿盛资本    150-500人
# 6870                                   NaN               亿盛资本    150-500人
# 6871                                   NaN               亿盛资本    150-500人
# 6872                                   NaN               亿盛资本    150-500人
# 6873                                   NaN               亿盛资本    150-500人
# 6874                                   NaN               亿盛资本    150-500人
# 6875                                   NaN               亿盛资本    150-500人
#
#                                      businessZones  firstType      secondType  \
# 0                                           ['张江']         技术            数据开发
# 1                           ['五里桥', '打浦桥', '制造局路']         技术            数据开发
# 2                                          ['打浦桥']         设计            数据分析
# 3                           ['龙华', '上海体育场', '万体馆']      市场与销售            数据分析
# 4                            ['上海影城', '新华路', '虹桥']         技术            软件开发
# 5                                              NaN        金融类      天使投资/VC/PE
# 6                            ['龙华', '植物园', '上海南站']         技术            后端开发
# 7                           ['黄兴公园', '长白新村', '延吉']  产品/需求/项目类       产品设计/需求分析
# 8                        ['上海电视台', '南京西路', '人民广场']         技术            后端开发
# 9                            ['漕宝路', '万源城', '东兰路']         技术            后端开发
# 10                           ['万源城', '漕宝路', '东兰路']         技术            后端开发
# 11                                             NaN         设计            用户研究
# 12                            ['梅陇', '南方商城', '古美']         技术            软件开发
# 13                         ['肇嘉浜路', '徐家汇', '交通大学']      市场与销售           市场/营销
# 14                             ['虹桥', '古北', '虹梅路']         技术            后端开发
# 15                          ['五里桥', '打浦桥', '制造局路']         技术            后端开发
# 16                                             NaN         技术            后端开发
# 17                           ['龙华', '植物园', '上海南站']         运营              运营
# 18                                         ['淮海路']         金融      天使投资/VC/PE
# 19                                          ['张江']        金融类  金融类-天使投资/VC/PE
# 20                                             NaN         技术            后端开发
# 21                                             NaN         金融      天使投资/VC/PE
# 22                                   ['田林', '徐家汇']      市场与销售            数据分析
# 23                                          ['龙华']      市场与销售             供应链
# 24                                             NaN  产品/需求/项目类            数据分析
# 25                            ['东外滩', '陆家嘴', '外滩']      市场与销售            数据分析
# 26                          ['淮海路', '人民广场', '老西门']         职能            人力资源
# 27                                          ['唐镇']         技术            后端开发
# 28                          ['五里桥', '打浦桥', '制造局路']         技术            后端开发
# 29                          ['龙华', '上海体育场', '万体馆']      市场与销售            数据分析
# ...                                            ...        ...             ...
# 6846                                       ['长椿街']         产品      产品经理/产品设计师
# 6847                                           NaN         运营              客服
# 6848                          ['朝外', '朝阳门', '东大桥']         金融             投融资
# 6849                                           NaN         设计            用户研究
# 6850                                 ['回龙观', '龙泽']         技术            数据开发
# 6851                         ['魏公村', '中关村', '皂君庙']      市场与销售            数据分析
# 6852                                        ['望京']      市场与销售            数据分析
# 6853                         ['菜市口', '陶然亭', '白纸坊']         技术          高端技术职位
# 6854                         ['亮马桥', '三元桥', '左家庄']         技术            后端开发
# 6855           ['珠市口', '磁器口', '新世界', '珠市口', '磁器口']         运营              编辑
# 6856                          ['亮马桥', '三元桥', '燕莎']         金融      天使投资/VC/PE
# 6857                          ['上地', '西二旗', '马连洼']         设计            数据分析
# 6858                           ['大望路', '红庙', '华贸']      市场与销售            数据分析
# 6859                                           NaN        金融类             管理岗
# 6860                          ['朝外', '朝阳门', '东大桥']         金融             投融资
# 6861                          ['亮马桥', '三元桥', '燕莎']         金融      天使投资/VC/PE
# 6862                                           NaN      市场与销售              销售
# 6863                                           NaN         运营              运营
# 6864                                ['酒仙桥', '姚家园']         金融      天使投资/VC/PE
# 6865  ['团结湖', '朝阳公园', '三里屯', '团结湖', '朝阳公园', '三里屯']         金融             投融资
# 6866                                           NaN      市场与销售              销售
# 6867                        ['德胜门', '新街口', '北太平庄']         技术            后端开发
# 6868                                           NaN         其它           教育|培训
# 6869                                           NaN        金融类              风控
# 6870                                           NaN  市场/商务/销售类              销售
# 6871                                           NaN  市场/商务/销售类              销售
# 6872                                           NaN  产品/需求/项目类            项目管理
# 6873                                           NaN         其他         房地产|建筑业
# 6874                                           NaN  市场/商务/销售类              销售
# 6875                                           NaN        金融类              风控
#
#      education industryField  positionId  \
# 0           硕士         移动互联网     2537336
# 1           本科            金融     2427485
# 2           本科         移动互联网     2511252
# 3           本科     企业服务,数据服务     2427530
# 4           本科            其他     2245819
# 5           本科            金融     2580543
# 6           本科    移动互联网,电子商务     1449715
# 7           硕士            金融     2568628
# 8           本科    移动互联网,医疗健康     2416852
# 9           本科          电子商务     1605795
# 10          本科      移动互联网,游戏     2157863
# 11          本科      电子商务,O2O     2548985
# 12          本科         移动互联网     2392425
# 13          本科      移动互联网,金融     1243515
# 14          硕士     电子商务,社交网络     2392372
# 15          本科            金融     2427555
# 16          硕士     企业服务,数据服务     2414480
# 17          本科    移动互联网,电子商务     2320870
# 18          本科            金融     2411279
# 19          本科          数据服务     2527100
# 20          本科      移动互联网,金融     2561181
# 21          硕士            金融     2501433
# 22          本科          数据服务     2517307
# 23          本科          电子商务     2388082
# 24          本科          电子商务     2531473
# 25          本科          数据服务     2168175
# 26          大专            招聘     2463114
# 27          本科       金融,数据服务     2428072
# 28          本科            金融     2427495
# 29          本科     企业服务,数据服务     2427570
# ...        ...           ...         ...
# 6846        本科       数据服务,其他     2542305
# 6847        大专            其他     2336832
# 6848        大专        金融,O2O     2455223
# 6849        大专         移动互联网     2551222
# 6850        本科          信息安全     2436339
# 6851        本科      移动互联网,金融     2442908
# 6852        硕士     企业服务,医疗健康     2402638
# 6853        本科       金融,数据服务     1867911
# 6854        硕士    移动互联网,数据服务     1043707
# 6855        本科     电子商务,文化娱乐     1693200
# 6856        硕士       金融,数据服务     2051982
# 6857        本科    移动互联网,数据服务      427065
# 6858        大专       文化娱乐,游戏     2380710
# 6859        大专         金融、教育     2474401
# 6860        大专        金融,O2O     2472045
# 6861        硕士       金融,数据服务     2051994
# 6862        本科            教育     2344828
# 6863        本科     企业服务,广告营销     2390054
# 6864        本科      移动互联网,金融     2412885
# 6865        不限      金融,移动互联网     1702627
# 6866        不限    电子商务,移动互联网     2465479
# 6867        本科    移动互联网,数据服务     2093199
# 6868        大专         金融、教育     2466098
# 6869        不限         金融、教育     2465818
# 6870        大专         金融、教育     2469665
# 6871        大专         金融、教育     2469682
# 6872        大专         金融、教育     2469686
# 6873        大专         金融、教育     2470949
# 6874        大专         金融、教育     2465839
# 6875        不限         金融、教育     2471674
#
#                                     positionAdvantage  \
# 0                                                知名平台
# 1                                挑战机会,团队好,与大牛合作,工作环境好
# 2                                          时间自由,领导nic
# 3                                 五险一金 绩效奖金 带薪年假 节日福利
# 4                                              在大牛下指导
# 5                                 留用机会,精品投行,优秀团队,氛围轻松
# 6                                       薪资福利待遇好，晋升空间大
# 7                                                健康体检
# 8                                 扁平管理,上升空间大,领导好,弹性工作
# 9                                         向大牛学习，有留司机会
# 10                                带薪年假 节日福利 出国机会 萌妹纸多
# 11                                          可转正,成长空间大
# 12                                        有爱的同事,欢快的氛围
# 13                                   工资自己定，期权任性发，半年晋升
# 14                                旺旺集团旗下电商，扁平管理，人性化环境
# 15                                机会挑战,技术牛,团队年轻,工作环境好
# 16                                大牛团队，奶妈助攻，六险一金，不要不来
# 17                                  足球氛围,福利多,空间大,免费午餐
# 18                                     资深团队；交通便利；考虑留用
# 19                                   互联网VC,活力团队,资深创投人
# 20                                              丰厚年终将
# 21                                          按日计酬,氛围轻松
# 22                               五险一金、带薪年假、员工旅游、弹性工作日
# 23                                晋升机会,专业培训,美味三餐,美女老板
# 24                             专业团队,薪酬福利优,免费化妆品,工作氛围好
# 25                                  新兴产业,跨国平台,团队氛围,薪资
# 26                                              福利待遇佳
# 27                                银联下属,金融互联网,技术开发,待遇佳
# 28                              机会挑战,团队技术牛,团队年轻,工作环境好
# 29                                五险一金 绩效奖金 带薪年假 节日福利
# ...                                               ...
# 6846                              上市公司背景、独立运营团队、提升空间大
# 6847                                    帅哥美女团队人好心善有才华
# 6848                              弹性工作 朝九晚六 周末双休 员工福利
# 6849                            五险一金 庆生礼物 带薪年假 高温话费补贴
# 6850                               依托学校,五险一金,假期多,氛围轻松
# 6851                                        五险一金、弹性工作
# 6852                              晋升空间,五险一金,带薪年假,弹性工作
# 6853                               银行大数据风控分析，海量交易数据实操
# 6854                                  大量纯洁的数据，等你用算法挑逗
# 6855                              中央媒体、专车接送、五险一金、补充医疗
# 6856                                   发展前景 技术培训 晋升通道
# 6857                                      技术含量高，发展前景好
# 6858                                 双休,五险一金,年底13薪,餐补
# 6859                             双休，五险，餐补，房补，带薪年假，交通补
# 6860                                   周末双休 早九晚六 弹性工作
# 6861                                   五险一金 晋升通道 发展前景
# 6862                             帮助程序员赴美做IT，享受高薪高品质生活
# 6863                             高端管理,带薪培训,优秀合伙人,广阔晋升
# 6864                                  任选岗位，找到最适合的发展方向
# 6865                            五险一金 年终奖 领导nice 发展空间大
# 6866                            无责底薪+高提成+五险+年底双薪+带薪年假
# 6867                               以解决技术难题为乐趣的工作最有吸引力
# 6868                                           薪资高待遇好
# 6869                             这是一个自我追寻的时代来亿盛资本看看吧。
# 6870                                      工作自由、法定假日休息
# 6871                                 高薪双休五险一金时间自由朝九晚五
# 6872                              高薪五险一金双休朝九晚五带薪年假20天
# 6873                               高薪五险一金双休朝九晚五无加班可培训
# 6874  高薪&nbsp;无加班&nbsp;&nbsp;双休&nbsp;&nbsp;五险一金&nbsp;
# 6875                                        挑战高薪，挑战自我
#
#                      positionName  \
# 0                           数据分析师
# 1             数据分析师-CR2017-SH2909
# 2                           数据分析师
# 3                  大数据业务分析师【数云校招】
# 4                      BI开发/数据分析师
# 5                           助理分析师
# 6                           数据工程师
# 7                 数据咨询顾问(2017年毕业)
# 8                    数据处理工程师（实习生）
# 9                         数据处理实习生
# 10                     大数据平台开发实习生
# 11                    数据分析专员（实习生）
# 12             BI数据分析实习生（2017年毕业）
# 13                           数据专员
# 14                数据工程师(大数据方向实习生)
# 15          数据研发工程师-CR2017-SH2913
# 16                     大数据工程师【校招】
# 17                          足球分析师
# 18                            分析师
# 19                            分析师
# 20                          数据工程师
# 21                       分析师（实习生）
# 22                         商业数据分析
# 23                         数据分析专员
# 24                         商业数据分析
# 25                     品牌保护分析师实习生
# 26                   数据合同管理助理（本部）
# 27                银联数据2017年校园招聘信息
# 28          数据系统工程师-CR2017-SH2907
# 29                    需求分析师【数云校招】
# ...                           ...
# 6846                       数据产品经理
# 6847               数据客服专员（双休五险一金）
# 6848                金融分析师/操盘手/交易员
# 6849                       数据分析专员
# 6850                        大数据研发
# 6851                       数据分析专员
# 6852                       商业数据分析
# 6853                     大数据开发工程师
# 6854                     大数据算法实习生
# 6855                       互联网分析师
# 6856                        评级分析师
# 6857                       数据分析助理
# 6858                       数据分析专员
# 6859                  高薪聘金融交易员分析师
# 6860                        金融分析师
# 6861                     金融/经济分析师
# 6862                   大数据程序员赴美项目
# 6863       数据分析（高管近距离+高薪资保证+晋升广阔）
# 6864                      分析师-实习生
# 6865  金融二级市场证券分析师／交易员／操盘手 零基础带薪培训
# 6866                     数据中心场地销售
# 6867                     爬虫数据-实习生
# 6868                        分析师助理
# 6869                       交易员分析师
# 6870                        外汇分析师
# 6871        金融证券分析师&nbsp;&nbsp;助理
# 6872             金融证券分析师&nbsp;可培训
# 6873      金融证券分析师&nbsp;讲师&nbsp;助理
# 6874                金融证券分析师助理讲师助理
# 6875           1W五险双休诚聘金融分析师助理可兼职
#
#                                          positionLables   salary workYear
# 0                         ['分析师', '数据分析', '数据挖掘', '数据']    7k-9k    应届毕业生
# 1                         ['分析师', '数据分析', '数据挖掘', '数据']  10k-15k    应届毕业生
# 2                                 ['分析师', '数据分析', '数据']    4k-6k    应届毕业生
# 3                            ['商业', '分析师', '大数据', '数据']    6k-8k    应届毕业生
# 4                           ['分析师', '数据分析', '数据', 'BI']    2k-3k    应届毕业生
# 5                     ['实习', '投资', 'FA', '行业研究', '分析师']  10k-15k    应届毕业生
# 6                                                ['数据']   7k-14k    应届毕业生
# 7                    ['需求分析', '顾问', '咨询', '咨询顾问', '数据']    5k-7k    应届毕业生
# 8                                        ['后端开发', '数据']    4k-8k    应届毕业生
# 9                                                ['数据']    2k-4k    应届毕业生
# 10                                  ['平台', '大数据', '数据']    5k-6k    应届毕业生
# 11                                       ['数据分析', '数据']    2k-4k    应届毕业生
# 12                                 ['数据分析', '数据', 'BI']    2k-3k    应届毕业生
# 13                                               ['数据']    4k-6k    应届毕业生
# 14                                        ['大数据', '数据']    4k-8k    应届毕业生
# 15                                               ['数据']  10k-15k    应届毕业生
# 16                                        ['大数据', '数据']  10k-15k    应届毕业生
# 17                                        ['分析师', '内容']    6k-8k    应届毕业生
# 18                                              ['分析师']    2k-3k    应届毕业生
# 19                                              ['分析师']    3k-4k    应届毕业生
# 20                                               ['数据']  10k-18k    应届毕业生
# 21                                              ['分析师']    3k-6k    应届毕业生
# 22                           ['商业', '数据分析', '数据', 'BI']    6k-8k    应届毕业生
# 23                                 ['数据分析', '仓储', '数据']    4k-6k    应届毕业生
# 24                           ['商业', '数据分析', '数据', 'BI']    4k-6k    应届毕业生
# 25                                  ['商业', '分析师', '品牌']    2k-3k    应届毕业生
# 26                                               ['数据']    4k-5k    应届毕业生
# 27                              ['招聘', '高校', 'C', '数据']  10k-20k    应届毕业生
# 28                                         ['数据', '系统']  10k-15k    应届毕业生
# 29                                ['商业', '分析师', '需求分析']    6k-8k    应届毕业生
# ...                                                 ...      ...      ...
# 6846                               ['产品经理', '产品', '数据']   7k-12k       不限
# 6847                                       ['客服', '数据']    4k-6k       不限
# 6848                                      ['分析师', '金融']   8k-10k       不限
# 6849                                     ['数据分析', '数据']    4k-6k       不限
# 6850                              ['大数据', '数据挖掘', '数据']   8k-10k       不限
# 6851                               ['商业', '数据分析', '数据']    4k-6k       不限
# 6852                         ['商业', '数据分析', '数据', 'BI']    4k-8k       不限
# 6853                               ['大数据', '数据库', '数据']  15k-30k       不限
# 6854                                ['大数据', '数据', '算法']    4k-6k       不限
# 6855                                            ['分析师']    4k-8k       不限
# 6856                                            ['分析师']   6k-10k       不限
# 6857                                     ['数据分析', '数据']   5k-10k       不限
# 6858                               ['商业', '数据分析', '数据']    4k-6k       不限
# 6859                        ['总监', '部门主管', '经理', '分析师']  10K-20K       不限
# 6860                                      ['分析师', '金融']   8k-10k       不限
# 6861                                      ['分析师', '金融']   6k-10k       不限
# 6862                                      ['大数据', '数据']  10k-20k       不限
# 6863                                     ['数据分析', '数据']   8k-16k       不限
# 6864                                            ['分析师']    4k-6k       不限
# 6865                                ['分析师', '金融', '证券']  15k-30k       不限
# 6866                                 ['销售', '销售', '数据']    3k-6k       不限
# 6867                                       ['爬虫', '数据']    3k-6k       不限
# 6868                                    ['分析师', '数据分析']   8K-16K       不限
# 6869                        ['风控', '经理', '行业研究', '分析师']   5K-10K       不限
# 6870                                    ['分析师', '资金管理']   8K-10K       不限
# 6871                                ['分析师', '金融', '证券']  10K-20K       不限
# 6872  ['项目管理', '专员', '助理', '实习生', '风控', '采购', '分析师',...  15K-30K       不限
# 6873  ['分析师', '职业培训', '教育', '培训', '金融', '证券', '股票', ...  15K-30K       不限
# 6874  ['实习生', '主管', '经理', '顾问', '销售', '客户代表', '分析师',...  10K-20K       不限
# 6875                                      ['分析师', '金融']   8K-15K       不限
#
# [6876 rows x 17 columns]

# %%
#由于positionId是职位ID，值唯一，用len函数计算出唯一值共有5031个，说明有多出来的重复值
len(df.positionId.unique())
# Out:
# 5031

# %%
#删去重复值
df_duplicates = df.drop_duplicates(subset='positionId',keep='first')
df_duplicates.head()
# Out:
#   city    companyFullName  companyId                  companyLabelList  \
# 0   上海     纽海信息技术(上海)有限公司       8581  ['技能培训', '节日礼物', '带薪年假', '岗位晋升']
# 1   上海   上海点荣金融信息服务有限责任公司      23177  ['节日礼物', '带薪年假', '岗位晋升', '扁平管理']
# 2   上海     上海晶樵网络信息技术有限公司      57561  ['技能培训', '绩效奖金', '岗位晋升', '管理规范']
# 3   上海  杭州数云信息技术有限公司上海分公司       7502  ['绩效奖金', '股票期权', '五险一金', '通讯津贴']
# 4   上海     上海银基富力信息技术有限公司     130876  ['年底双薪', '通讯津贴', '定期体检', '绩效奖金']
#
#   companyShortName companySize           businessZones firstType secondType  \
# 0              1号店     2000人以上                  ['张江']        技术       数据开发
# 1              点融网   500-2000人  ['五里桥', '打浦桥', '制造局路']        技术       数据开发
# 2              SPD     50-150人                 ['打浦桥']        设计       数据分析
# 3               数云    150-500人  ['龙华', '上海体育场', '万体馆']     市场与销售       数据分析
# 4             银基富力      15-50人   ['上海影城', '新华路', '虹桥']        技术       软件开发
#
#   education industryField  positionId     positionAdvantage  \
# 0        硕士         移动互联网     2537336                  知名平台
# 1        本科            金融     2427485  挑战机会,团队好,与大牛合作,工作环境好
# 2        本科         移动互联网     2511252            时间自由,领导nic
# 3        本科     企业服务,数据服务     2427530   五险一金 绩效奖金 带薪年假 节日福利
# 4        本科            其他     2245819                在大牛下指导
#
#           positionName                 positionLables   salary workYear
# 0                数据分析师  ['分析师', '数据分析', '数据挖掘', '数据']    7k-9k    应届毕业生
# 1  数据分析师-CR2017-SH2909  ['分析师', '数据分析', '数据挖掘', '数据']  10k-15k    应届毕业生
# 2                数据分析师          ['分析师', '数据分析', '数据']    4k-6k    应届毕业生
# 3       大数据业务分析师【数云校招】     ['商业', '分析师', '大数据', '数据']    6k-8k    应届毕业生
# 4           BI开发/数据分析师    ['分析师', '数据分析', '数据', 'BI']    2k-3k    应届毕业生

# %%
df_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5031 entries, 0 to 6766
# Data columns (total 17 columns):
# city                 5031 non-null object
# companyFullName      5031 non-null object
# companyId            5031 non-null int64
# companyLabelList     4529 non-null object
# companyShortName     5031 non-null object
# companySize          5031 non-null object
# businessZones        3535 non-null object
# firstType            5027 non-null object
# secondType           5028 non-null object
# education            5031 non-null object
# industryField        5031 non-null object
# positionId           5031 non-null int64
# positionAdvantage    5031 non-null object
# positionName         5031 non-null object
# positionLables       5007 non-null object
# salary               5031 non-null object
# workYear             5031 non-null object
# dtypes: int64(2), object(15)
# memory usage: 707.5+ KB

# %%
#处理薪资上下限
def cut_word(word,method):
    position = word.find('-')
    if position != -1:
        bottomSalary = word[:position-1]
        topSalary = word[position+1:-1]
    else:
        bottomSalary = word[:word.upper().find('K')]
        topSalary = bottomSalary
    if method == 'bottom':
        return bottomSalary
    else:
        return topSalary

# %%
df_duplicates['bottomSalary'] = df_duplicates.salary.apply(cut_word,method='bottom')
df_duplicates['topSalary'] = df_duplicates.salary.apply(cut_word,method='top')
# Out:
# d:\software\python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# d:\software\python\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#数据类型转换为数字
df_duplicates.bottomSalary = df_duplicates.bottomSalary.astype('int')
df_duplicates.topSalary = df_duplicates.topSalary.astype('int')

#求平均薪资
df_duplicates['avgSalary'] = df_duplicates.apply(lambda x:(x.bottomSalary+x.topSalary)/2, axis=1)
# Out:
# d:\software\python\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# d:\software\python\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_clean = df_duplicates[['city','companyShortName','companySize','education','positionName','positionLables','workYear','avgSalary']]
df_clean.head()
# Out:
#   city companyShortName companySize education         positionName  \
# 0   上海              1号店     2000人以上        硕士                数据分析师
# 1   上海              点融网   500-2000人        本科  数据分析师-CR2017-SH2909
# 2   上海              SPD     50-150人        本科                数据分析师
# 3   上海               数云    150-500人        本科       大数据业务分析师【数云校招】
# 4   上海             银基富力      15-50人        本科           BI开发/数据分析师
#
#                   positionLables workYear  avgSalary
# 0  ['分析师', '数据分析', '数据挖掘', '数据']    应届毕业生        8.0
# 1  ['分析师', '数据分析', '数据挖掘', '数据']    应届毕业生       12.5
# 2          ['分析师', '数据分析', '数据']    应届毕业生        5.0
# 3     ['商业', '分析师', '大数据', '数据']    应届毕业生        7.0
# 4    ['分析师', '数据分析', '数据', 'BI']    应届毕业生        2.5

# %%
#一般分类数据用value_counts，数值数据用describe，这是最常用的两个统计函数
df_clean.city.value_counts()
# Out:
# 北京    2347
# 上海     979
# 深圳     527
# 杭州     406
# 广州     335
# 成都     135
# 南京      83
# 武汉      69
# 西安      38
# 苏州      37
# 厦门      30
# 长沙      25
# 天津      20
# Name: city, dtype: int64

# %%
df_clean.describe()
# Out:
#          avgSalary
# count  5031.000000
# mean     17.111409
# std       8.996242
# min       1.500000
# 25%      11.500000
# 50%      15.000000
# 75%      22.500000
# max      75.000000

# %%
import matplotlib.pyplot as plot

#%matplotlib inline是jupyter自带的方式，允许图表在cell中输出
% matplotlib inline

plot.style.use('ggplot')

# %%
df_clean.avgSalary.hist()

# %%
df_clean.avgSalary.hist(bins=15)

# %%
df_clean.boxplot(column='avgSalary',by='city',figsize=(9,7))

# %%
from matplotlib.font_manager import FontProperties
font_zh = FontProperties(fname="C:\Windows\Fonts\STZHONGS.TTF")

ax = df_clean.boxplot(column='avgSalary',by='city',figsize=(9,7))
for label in ax.get_xticklabels():
    label.set_fontproperties(font_zh)

# %%
ax = df_clean.boxplot(column='avgSalary',by='workYear',figsize=(9,7))
for label in ax.get_xticklabels():
    label.set_fontproperties(font_zh)

# %%
df_sh_bj = df_clean[df_clean['city'].isin(['上海','北京'])]
ax = df_sh_bj.boxplot(column='avgSalary',by=['education','city'],figsize=(14,6))
for label in ax.get_xticklabels():
    label.set_fontproperties(font_zh)

# %%
df_clean.groupby('city').count()
# Out:
#       companyShortName  companySize  education  positionName  positionLables  \
# city
# 上海                 979          979        979           979             973
# 北京                2347         2347       2347          2347            2336
# 南京                  83           83         83            83              82
# 厦门                  30           30         30            30              30
# 天津                  20           20         20            20              20
# 广州                 335          335        335           335             333
# 成都                 135          135        135           135             134
# 杭州                 406          406        406           406             405
# 武汉                  69           69         69            69              69
# 深圳                 527          527        527           527             525
# 苏州                  37           37         37            37              37
# 西安                  38           38         38            38              38
# 长沙                  25           25         25            25              25
#
#       workYear  avgSalary
# city
# 上海         979        979
# 北京        2347       2347
# 南京          83         83
# 厦门          30         30
# 天津          20         20
# 广州         335        335
# 成都         135        135
# 杭州         406        406
# 武汉          69         69
# 深圳         527        527
# 苏州          37         37
# 西安          38         38
# 长沙          25         25

# %%
df_clean.groupby('city').mean()
# Out:
#       avgSalary
# city
# 上海    17.280388
# 北京    18.688539
# 南京    10.951807
# 厦门    10.966667
# 天津     8.250000
# 广州    12.702985
# 成都    12.848148
# 杭州    16.455665
# 武汉    11.297101
# 深圳    17.591082
# 苏州    14.554054
# 西安    10.671053
# 长沙     9.600000

# %%
df_clean.groupby(['city','education']).mean().unstack()
# Out:
#            avgSalary
# education         不限    博士         大专         本科         硕士
# city
# 上海         14.051471  15.0  13.395455  17.987552  19.180000
# 北京         15.673387  25.0  12.339474  19.435802  19.759740
# 南京          7.000000   NaN   9.272727  11.327869  13.500000
# 厦门         12.500000   NaN   6.785714  11.805556  15.750000
# 天津          3.500000   NaN   5.500000   9.300000        NaN
# 广州          9.250000   NaN   8.988095  14.170259  14.571429
# 成都         10.562500   NaN  11.000000  13.520202  12.750000
# 杭州         18.269231   NaN  12.327586  16.823432  20.710526
# 武汉         10.950000   NaN  11.214286  11.500000   7.000000
# 深圳         15.100000  35.0  13.898936  18.532911  18.029412
# 苏州               NaN   NaN  14.600000  14.310345  16.833333
# 西安          8.666667   NaN   8.150000  12.208333   5.000000
# 长沙          7.642857   NaN   9.000000  10.633333   9.000000

# %%
df_clean.groupby(['city','education']).avgSalary.count().unstack()
# Out:
# education     不限   博士     大专      本科     硕士
# city
# 上海          68.0  3.0  110.0   723.0   75.0
# 北京         124.0  2.0  190.0  1877.0  154.0
# 南京           5.0  NaN   11.0    61.0    6.0
# 厦门           3.0  NaN    7.0    18.0    2.0
# 天津           1.0  NaN    4.0    15.0    NaN
# 广州          12.0  NaN   84.0   232.0    7.0
# 成都           8.0  NaN   26.0    99.0    2.0
# 杭州          26.0  NaN   58.0   303.0   19.0
# 武汉          10.0  NaN   14.0    44.0    1.0
# 深圳          20.0  1.0   94.0   395.0   17.0
# 苏州           NaN  NaN    5.0    29.0    3.0
# 西安           3.0  NaN   10.0    24.0    1.0
# 长沙           7.0  NaN    2.0    15.0    1.0

# %%
df_clean.groupby('companyShortName').avgSalary.agg(['count','mean']).sort_values(by='count',ascending=False)
# Out:
#                   count       mean
# companyShortName
# 美团点评                175  21.862857
# 滴滴出行                 64  27.351562
# 百度                   44  19.136364
# 网易                   36  18.208333
# 今日头条                 32  17.125000
# 腾讯                   32  22.437500
# 京东                   32  20.390625
# 百度外卖                 31  17.774194
# 个推                   31  14.516129
# TalkingData          28  16.160714
# 宜信                   27  22.851852
# 搜狐媒体                 23  25.739130
# 饿了么                  23  19.391304
# Gridsum 国双           23  19.086957
# 去哪儿网                 22  17.863636
# 汽车之家                 21  18.952381
# 乐视                   19  21.052632
# 京东商城                 19  23.763158
# 滴滴出行（小桔科技）           18  34.722222
# 人人行(借贷宝)             17  21.088235
# 链家网                  16  17.250000
# 嘉琪科技                 16  24.625000
# 百融金服                 16  17.500000
# 易到用车                 16  16.156250
# 通联数据                 16   8.843750
# 星河互联集团               16  29.062500
# 陌陌                   15  18.566667
# 买单侠                  15  18.600000
# 有数金服                 15  13.700000
# 返利网                  15  23.833333
# ...                 ...        ...
# 图灵机器人                 1  32.500000
# 国金证券                  1  37.500000
# 大观资本                  1   4.500000
# 大麦网                   1  55.000000
# 天会创投                  1   5.000000
# 天会皓闻                  1   3.500000
# 太子龙                   1   4.000000
# 天骄尚学                  1  10.000000
# 天阳科技                  1  11.500000
# 天闻数媒                  1  15.000000
# 天融互联                  1  20.000000
# 天育                    1   7.000000
# 天翼阅读文化传播有限公司          1  15.000000
# 天眼互联                  1   7.500000
# 天相瑞通                  1   7.500000
# 天玑科技                  1  15.000000
# 天源迪科                  1  31.500000
# 天津赛维斯科技有限公司           1   5.000000
# 天津航空                  1   9.000000
# 天津美源星                 1   3.500000
# 天津小猫                  1  11.500000
# 天气宝                   1  15.000000
# 天星资本                  1  11.000000
# 天弘基金                  1  25.000000
# 天尧信息                  1  15.000000
# 天宝                    1  22.500000
# 天天果园                  1  17.500000
# 天地汇                   1  14.000000
# 天同                    1  15.000000
# 龙浩通信                  1   5.000000
#
# [2243 rows x 2 columns]

# %%
df_clean.groupby('companyShortName').avgSalary.agg(lambda x: max(x)-min(x))
# Out:
# companyShortName
# 12580               0.0
# 12家全国性股份制商业银行之一     0.0
# 1号店                22.0
# 2345.com            4.0
# 360                22.0
# 360企业安全             0.0
# 360金融               0.0
# 4399                0.0
# 4399游戏              5.0
# 500.com集团          15.0
# 51Talk 无忧英语        15.0
# 51信用卡管家            20.0
# 51爱趣淘               0.0
# 55海淘                0.0
# 58到家               30.0
# 58车                 0.0
# AIRCOS              0.0
# APUS Group         27.0
# AbleCloud           2.5
# Adhub               0.0
# Alading Bank        0.0
# Asia-analytics      0.0
# Avazu Holding       0.0
# BBD                63.5
# BOE                 0.0
# BTCC                3.0
# BUGBANK             0.0
# BW                  5.5
# Baca                0.0
# Base FX             0.0
#                    ...
# 驻云                  0.0
# 高伟达软件股份有限公司        17.5
# 高升控股               12.5
# 高德联讯                0.0
# 高校邦                 0.0
# 高阳通联                0.0
# 鬼吹灯3D               0.0
# 魔品科技                0.0
# 魔秀科技                2.5
# 魔窗                 10.0
# 魔蝎数据                0.0
# 鹏元数据技术              0.0
# 鹰眼数据                0.0
# 鹿公关                 0.0
# 麦优                  0.0
# 麦博游戏 MYBO           0.0
# 麦图科技                0.0
# 麦子金服               17.5
# 麦萌漫画                0.0
# 麻小外卖                8.5
# 黄太吉传统美食             0.0
# 黄金宝                 0.0
# 黑石互联网               0.0
# 黑马金融                0.0
# 鼎治泰达财富              0.0
# 齐家网                 6.0
# 齐聚科技（原呱呱视频）         0.0
# 龙信数据                7.0
# 龙宝斋财富               0.0
# 龙浩通信                0.0
# Name: avgSalary, Length: 2243, dtype: float64

# %%
def topN(df, n=5):
    counts = df.value_counts()
    return counts.sort_values(ascending=False)[:n]

# %%
df_clean.groupby('city').companyShortName.apply(topN)
# Out:
# city
# 上海    饿了么                 23
#       美团点评                19
#       买单侠                 15
#       返利网                 15
#       点融网                 11
# 北京    美团点评               156
#       滴滴出行                60
#       百度                  39
#       今日头条                32
#       百度外卖                31
# 南京    途牛旅游网                8
#       通联数据                 7
#       中地控股                 6
#       创景咨询                 5
#       南京领添                 3
# 厦门    美图公司                 4
#       厦门融通信息技术有限责任公司       2
#       Datartisan 数据工匠      2
#       笨鸟社交                 1
#       4399                 1
# 天津    神州商龙                 2
#       闯先生Mr.Chuang         1
#       安正软件                 1
#       数极客                  1
#       众嘉禾励                 1
# 广州    探迹                  11
#       唯品会                  9
#       广东亿迅                 8
#       阿里巴巴移动事业群-UC         7
#       聚房宝                  6
#                         ...
# 杭州    个推                  22
#       网易                  15
#       有数金服                15
#       同花顺                 14
#       51信用卡管家             11
# 武汉    斗鱼直播                 5
#       武汉物易云通网络科技           4
#       卷皮                   4
#       榆钱金融                 3
#       远光软件武汉研发中心           2
# 深圳    腾讯                  25
#       金蝶                  14
#       香港康宏金融集团            12
#       华为技术有限公司            12
#       顺丰科技有限公司             9
# 苏州    同程旅游                10
#       朗动网络科技               3
#       智慧芽                  3
#       食行生鲜                 2
#       思必驰科技                2
# 西安    思特奇Si-tech           4
#       天晓科技                 3
#       绿盟科技                 3
#       海航生态科技               2
#       全景数据                 2
# 长沙    芒果tv                 4
#       惠农                   3
#       思特奇Si-tech           2
#       高阳通联                 1
#       五八到家有限公司             1
# Name: companyShortName, Length: 65, dtype: int64

# %%
df_clean.groupby('city').positionName.apply(topN)
# Out:
# city
# 上海    数据分析师                      79
#       大数据开发工程师                   37
#       数据产品经理                     31
#       大数据工程师                     26
#       高级数据分析师                    20
# 北京    数据分析师                     238
#       数据产品经理                    121
#       大数据开发工程师                   69
#       分析师                        49
#       数据分析                       42
# 南京    数据分析师                       5
#       大数据开发工程师                    5
#       大数据工程师                      3
#       大数据架构师                      3
#       数据产品经理                      2
# 厦门    数据分析专员                      3
#       数据分析师                       3
#       大数据开发工程师                    2
#       大数据挖掘工程师                    1
#       数据分析经理/主管                   1
# 天津    数据分析师                       3
#       数据工程师                       2
#       业务/数据研究岗                    1
#       大数据工程师数据挖掘方向                1
#       高级需求分析师                     1
# 广州    数据分析师                      31
#       需求分析师                      23
#       大数据开发工程师                   13
#       数据分析专员                     10
#       高级数据分析师                     9
#                                ...
# 杭州    数据分析师                      44
#       大数据开发工程师                   22
#       数据产品经理                     15
#       数据仓库工程师                    11
#       数据分析                       10
# 武汉    大数据开发工程师                    6
#       数据分析师                       5
#       数据仓库工程师                     2
#       大数据架构师                      2
#       高级数据分析工程师                   2
# 深圳    数据分析师                      52
#       大数据开发工程师                   32
#       数据产品经理                     24
#       需求分析师                      21
#       大数据架构师                     11
# 苏州    数据分析师                       8
#       数据产品经理                      2
#       需求分析师                       2
#       数据报表开发工程师                   1
#       对话数据工程师（2017年校招）            1
# 西安    需求分析师                       5
#       数据分析师                       3
#       大数据开发工程师                    3
#       大数据工程师                      2
#       数据工程师                       1
# 长沙    数据工程师                       2
#       数据开发工程师                     2
#       文员/数据统计文员/数据分析文员/助理/专员      1
#       大数据开发工程师                    1
#       DBA数据分析师                    1
# Name: positionName, Length: 65, dtype: int64

# %%
ax = df_clean.groupby('city').mean().plot.bar()
for label in ax.get_xticklabels():
    label.set_fontproperties(font_zh)

# %%
ax = df_clean.groupby(['city','education']).mean().unstack().plot.bar(figsize=(14,6))
for label in ax.get_xticklabels():
    label.set_fontproperties(font_zh)
ax.legend(prop=font_zh)

# %%
plot.hist(x = df_clean[df_clean.city == '上海'].avgSalary,
         bins=15,
         normed=1,
         facecolor='blue',
         alpha=0.5)
plot.hist(x = df_clean[df_clean.city == '北京'].avgSalary,
         bins=15,
         normed=1,
         facecolor='red',
         alpha=0.5)
plot.show()
# Out:
# d:\software\python\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
bins = [0,3,5,10,15,20,30,100]
level = ['0-3','3-5','5-10','10-15','15-20','20-30','30+']
df_clean['level']=pd.cut(df_clean['avgSalary'],bins=bins,labels=level)
# Out:
# d:\software\python\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_clean[['avgSalary','level']]
# Out:
#       avgSalary  level
# 0           8.0   5-10
# 1          12.5  10-15
# 2           5.0    3-5
# 3           7.0   5-10
# 4           2.5    0-3
# 5          12.5  10-15
# 6          10.5  10-15
# 7           6.0   5-10
# 8           6.0   5-10
# 9           3.0    0-3
# 10          5.5   5-10
# 11          3.0    0-3
# 12          2.5    0-3
# 13          5.0    3-5
# 14          6.0   5-10
# 15         12.5  10-15
# 16         12.5  10-15
# 17          7.0   5-10
# 18          2.5    0-3
# 19          3.5    3-5
# 20         14.0  10-15
# 21          4.5    3-5
# 22          7.0   5-10
# 23          5.0    3-5
# 24          5.0    3-5
# 25          2.5    0-3
# 26          4.5    3-5
# 27         15.0  10-15
# 28         12.5  10-15
# 29          7.0   5-10
# ...         ...    ...
# 5019       30.0  20-30
# 5020       20.0  15-20
# 5021       11.5  10-15
# 5022        7.0   5-10
# 5023        6.5   5-10
# 5024        3.0    0-3
# 5025        6.0   5-10
# 5026        7.0   5-10
# 5027        7.5   5-10
# 5028        6.5   5-10
# 5029        5.0    3-5
# 5030        4.0    3-5
# 5031       12.5  10-15
# 5032        9.0   5-10
# 5033       11.5  10-15
# 5034       15.0  10-15
# 5035        9.0   5-10
# 5036       17.5  15-20
# 5037        4.5    3-5
# 5038        5.0    3-5
# 5039        7.0   5-10
# 5040       16.0  15-20
# 5041        3.5    3-5
# 5042        4.0    3-5
# 5043       11.5  10-15
# 6054       20.0  15-20
# 6330       22.5  20-30
# 6465       35.0    30+
# 6605        5.0    3-5
# 6766       22.5  20-30
#
# [5031 rows x 2 columns]

# %%
df_level = df_clean.groupby(['city','level']).avgSalary.count().unstack()
df_level_prop = df_level.apply(lambda x:x/x.sum(),axis=1)
ax = df_level_prop.plot.bar(figsize=(16,7),stacked=True)
for label_x in ax.get_xticklabels():
    label_x.set_fontproperties(font_zh)

# %%
word = df_clean.positionLables.str[1:-1].str.replace(' ','')
word.dropna().str.split(',').apply(pd.value_counts)
# Out:
#       '数据'  '数据分析'  '数据挖掘'  '分析师'  '大数据'  '商业'  'BI'  '投资'  '实习'  'FA'  ...   \
# 0      1.0     1.0     1.0    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      1.0     1.0     1.0    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2      1.0     1.0     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3      1.0     NaN     NaN    1.0    1.0   1.0   NaN   NaN   NaN   NaN  ...
# 4      1.0     1.0     NaN    1.0    NaN   NaN   1.0   NaN   NaN   NaN  ...
# 5      NaN     NaN     NaN    1.0    NaN   NaN   NaN   1.0   1.0   1.0  ...
# 6      1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7      1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8      1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9      1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10     1.0     NaN     NaN    NaN    1.0   NaN   NaN   NaN   NaN   NaN  ...
# 11     1.0     1.0     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 12     1.0     1.0     NaN    NaN    NaN   NaN   1.0   NaN   NaN   NaN  ...
# 13     1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 14     1.0     NaN     NaN    NaN    1.0   NaN   NaN   NaN   NaN   NaN  ...
# 15     1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 16     1.0     NaN     NaN    NaN    1.0   NaN   NaN   NaN   NaN   NaN  ...
# 17     NaN     NaN     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 18     NaN     NaN     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 19     NaN     NaN     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 20     1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 21     NaN     NaN     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 22     1.0     1.0     NaN    NaN    NaN   1.0   1.0   NaN   NaN   NaN  ...
# 23     1.0     1.0     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 24     1.0     1.0     NaN    NaN    NaN   1.0   1.0   NaN   NaN   NaN  ...
# 25     NaN     NaN     NaN    1.0    NaN   1.0   NaN   NaN   NaN   NaN  ...
# 26     1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 27     1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 28     1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 29     NaN     NaN     NaN    1.0    NaN   1.0   NaN   NaN   NaN   NaN  ...
# ...    ...     ...     ...    ...    ...   ...   ...   ...   ...   ...  ...
# 5019   1.0     NaN     NaN    NaN    1.0   NaN   NaN   NaN   NaN   NaN  ...
# 5020   NaN     NaN     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5021   1.0     1.0     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5022   1.0     1.0     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5023   NaN     NaN     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5024   1.0     1.0     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5025   1.0     1.0     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5026   1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5027   1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5028   1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5029   NaN     NaN     NaN    1.0    NaN   NaN   NaN   1.0   NaN   NaN  ...
# 5030   1.0     1.0     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5031   1.0     1.0     1.0    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5032   1.0     1.0     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5033   NaN     NaN     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5034   1.0     NaN     NaN    NaN    1.0   NaN   NaN   NaN   NaN   NaN  ...
# 5035   NaN     NaN     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5036   1.0     NaN     1.0    NaN    1.0   NaN   NaN   NaN   NaN   NaN  ...
# 5037   1.0     1.0     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5038   1.0     1.0     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5039   1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5040   1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5041   1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5042   1.0     NaN     NaN    NaN    NaN   1.0   NaN   NaN   NaN   NaN  ...
# 5043   1.0     NaN     NaN    NaN    1.0   NaN   NaN   NaN   NaN   NaN  ...
# 6054   1.0     1.0     NaN    1.0    NaN   NaN   1.0   NaN   NaN   NaN  ...
# 6330   NaN     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 6465   1.0     NaN     1.0    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 6605   NaN     NaN     NaN    1.0    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 6766   1.0     NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#       '性能测试'  '协议分析'  '在线'  '供应链'  '技术岗位'  '云平台'  'SEM'  'J2EE'  '文案'  '专利'
# 0        NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 1        NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 2        NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 3        NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 4        NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5        NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 6        NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 7        NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 8        NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 9        NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 10       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 11       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 12       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 13       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 14       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 15       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 16       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 17       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 18       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 19       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 20       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 21       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 22       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 23       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 24       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 25       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 26       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 27       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 28       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 29       NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# ...      ...     ...   ...    ...     ...    ...    ...     ...   ...   ...
# 5019     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5020     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5021     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5022     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5023     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5024     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5025     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5026     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5027     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5028     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5029     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5030     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5031     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5032     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5033     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5034     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5035     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5036     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5037     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5038     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5039     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5040     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5041     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5042     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 5043     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 6054     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 6330     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 6465     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 6605     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
# 6766     NaN     NaN   NaN    NaN     NaN    NaN    NaN     NaN   NaN   NaN
#
# [5007 rows x 267 columns]

# %%
df_word = word.dropna().str.split(',').apply(pd.value_counts)

# %%
df_word.unstack()
# Out:
# '数据'  0       1.0
#       1       1.0
#       2       1.0
#       3       1.0
#       4       1.0
#       5       NaN
#       6       1.0
#       7       1.0
#       8       1.0
#       9       1.0
#       10      1.0
#       11      1.0
#       12      1.0
#       13      1.0
#       14      1.0
#       15      1.0
#       16      1.0
#       17      NaN
#       18      NaN
#       19      NaN
#       20      1.0
#       21      NaN
#       22      1.0
#       23      1.0
#       24      1.0
#       25      NaN
#       26      1.0
#       27      1.0
#       28      1.0
#       29      NaN
#              ...
# '专利'  5019    NaN
#       5020    NaN
#       5021    NaN
#       5022    NaN
#       5023    NaN
#       5024    NaN
#       5025    NaN
#       5026    NaN
#       5027    NaN
#       5028    NaN
#       5029    NaN
#       5030    NaN
#       5031    NaN
#       5032    NaN
#       5033    NaN
#       5034    NaN
#       5035    NaN
#       5036    NaN
#       5037    NaN
#       5038    NaN
#       5039    NaN
#       5040    NaN
#       5041    NaN
#       5042    NaN
#       5043    NaN
#       6054    NaN
#       6330    NaN
#       6465    NaN
#       6605    NaN
#       6766    NaN
# Length: 1336869, dtype: float64

# %%
df_word.unstack().dropna().reset_index()
# Out:
#          level_0  level_1    0
# 0           '数据'        0  1.0
# 1           '数据'        1  1.0
# 2           '数据'        2  1.0
# 3           '数据'        3  1.0
# 4           '数据'        4  1.0
# 5           '数据'        6  1.0
# 6           '数据'        7  1.0
# 7           '数据'        8  1.0
# 8           '数据'        9  1.0
# 9           '数据'       10  1.0
# 10          '数据'       11  1.0
# 11          '数据'       12  1.0
# 12          '数据'       13  1.0
# 13          '数据'       14  1.0
# 14          '数据'       15  1.0
# 15          '数据'       16  1.0
# 16          '数据'       20  1.0
# 17          '数据'       22  1.0
# 18          '数据'       23  1.0
# 19          '数据'       24  1.0
# 20          '数据'       26  1.0
# 21          '数据'       27  1.0
# 22          '数据'       28  1.0
# 23          '数据'       30  1.0
# 24          '数据'       31  1.0
# 25          '数据'       32  1.0
# 26          '数据'       34  1.0
# 27          '数据'       35  1.0
# 28          '数据'       36  1.0
# 29          '数据'       37  1.0
# ...          ...      ...  ...
# 14205       '银行'     4037  1.0
# 14206     '数据模型'     4037  1.0
# 14207     '数据治理'     4037  1.0
# 14208     '数据治理'     4115  1.0
# 14209       '微信'     4084  1.0
# 14210   '数据挖掘分析'     4090  1.0
# 14211    '数据库开发'     4253  1.0
# 14212    '数据库开发'     4339  1.0
# 14213  'Node.js'     4351  1.0
# 14214       '音乐'     4396  1.0
# 14215       '音乐'     4546  1.0
# 14216     '系统集成'     4428  1.0
# 14217     '系统集成'     4917  1.0
# 14218     '战略扩建'     4549  1.0
# 14219       '法务'     4585  1.0
# 14220       '记者'     4628  1.0
# 14221    'storm'     4663  1.0
# 14222     '功能测试'     4688  1.0
# 14223     '安全测试'     4688  1.0
# 14224     '性能测试'     4688  1.0
# 14225     '协议分析'     4699  1.0
# 14226       '在线'     4723  1.0
# 14227      '供应链'     4786  1.0
# 14228     '技术岗位'     4797  1.0
# 14229      '云平台'     4925  1.0
# 14230      'SEM'     4964  1.0
# 14231     'J2EE'     4969  1.0
# 14232     'J2EE'     4980  1.0
# 14233       '文案'     4987  1.0
# 14234       '专利'     4997  1.0
#
# [14235 rows x 3 columns]

# %%
df_word_counts = df_word.unstack().dropna().reset_index().groupby('level_0').count()

# %%
from wordcloud import WordCloud
df_word_counts.index = df_word_counts.index.str.replace("'","")
wordcloud = WordCloud(font_path="C:\Windows\Fonts\STZHONGS.TTF",
                      width=900,height=400,
                      background_color='white')
f, axs = plot.subplots(figsize=(15,15))
wordcloud.fit_words(df_word_counts.level_1)
axs = plot.imshow(wordcloud)
plot.axis('off')
plot.show()
